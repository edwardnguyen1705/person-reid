# %%
# %cd ..
# Out:
# /home/hien/Documents/models/rep_reid

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="resnet50",
    activation=get_activations('LeakyReLU'),
    pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 224, 224), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       4.12 GMac
# Number of parameters:           23.51 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="resnet101",
    activation=get_activations('LeakyReLU'),
    pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 320, 320), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       16.02 GMac
# Number of parameters:           42.5 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="CSPDarknet53",
    activation=get_activations('LeakyReLU'),
    pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 256, 256), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       7.69 GMac
# Number of parameters:           26.62 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_S",
    activation=get_activations('LeakyReLU'),
    pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 300, 300), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       28.83 GMac
# Number of parameters:           20.18 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_M",
    activation=get_activations('LeakyReLU'),
    pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 380, 380), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       92.65 GMac
# Number of parameters:           52.86 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="MobileNetV3Large",
    activation=get_activations('LeakyReLU'),
    pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 224, 224), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       0.29 GMac
# Number of parameters:           4.7 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="Efficientnet_b0", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 224, 224), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       0.7 GMac
# Number of parameters:           4.01 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="Efficientnet_b1", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 240, 240), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       1.38 GMac
# Number of parameters:           6.51 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="Efficientnet_b2", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 260, 260), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       1.88 GMac
# Number of parameters:           7.7 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="Efficientnet_b3", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 300, 300), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       3.54 GMac
# Number of parameters:           10.7 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="Efficientnet_b4", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 380, 380), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       8.78 GMac
# Number of parameters:           17.55 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="Efficientnet_b5", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 456, 456), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       20.75 GMac
# Number of parameters:           28.34 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_5_b0", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 224, 224), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       0.84 GMac
# Number of parameters:           4.36 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_5_b1", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 240, 240), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       1.55 GMac
# Number of parameters:           7.11 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_5_b2", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 260, 260), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       2.24 GMac
# Number of parameters:           8.5 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_5_b3", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 300, 300), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       4.04 GMac
# Number of parameters:           11.63 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_5_b4", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 380, 380), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       10.18 GMac
# Number of parameters:           19.21 M

# %%
from torchinfo import summary
from ptflops import get_model_complexity_info

from models.activations import get_activations
from models.backbones import build_backbone

model = build_backbone(
    name="EfficientnetV2_5_b5", activation=get_activations("LeakyReLU"), pretrained=False
)[0]

macs, params = get_model_complexity_info(
    model.eval(), (3, 456, 456), as_strings=True, print_per_layer_stat=False, verbose=True
)

print("{:<30}  {:<8}".format("Computational complexity: ", macs))
print("{:<30}  {:<8}".format("Number of parameters: ", params))
# Out:
# ...
# Computational complexity:       24.3 GMac
# Number of parameters:           31.24 M
