# %% [markdown]
# ![image.png](attachment:a9167874-8d23-444c-a7b9-7c19d9bf829d.png)

# %%
import numpy as np

# %%
W1 = np.array([
    [0.2, -0.3],
    [0.4, 0.1],
])
x = np.array([0, 1])
b1 = np.array([-0.4, 0.2])

# %%
y1 = np.matmul(W1, x[:, None]) + b1[:, None]
y1
# Out:
# array([[-0.7],
#        [ 0.3]])

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
y2 = sigmoid(y1)
y2
# Out:
# array([[0.33181223],
#        [0.57444252]])

# %%
W2 = np.array([[-0.3, -0.2]])
b2 = np.array([0.1])

# %%
y3 = np.matmul(W2, y2) + b2[:, None]
y3
# Out:
# array([[-0.11443217]])

# %%
y4 = sigmoid(y3)
y4
# Out:
# array([[0.47142313]])

# %%
def mse(input, target):
    return np.square(input - target).mean()

# %%
loss = mse(y4, 1)
loss
# Out:
# 0.27939350315292383

# %%
def derivative_mse(input, target):
    return (2 * (input - target)).mean()

# %%
delta_y = derivative_mse(y4, 1)
delta_y
# Out:
# -1.0571537317777842

# %%
def derivate_sigmoid(x):
    return x * (1 - x)

# %%
delta_y3 = delta_y * derivate_sigmoid(y4)
delta_y3
# Out:
# array([[-0.26342512]])

# %%
delta_w2 = delta_y3 * (np.matmul(delta_y3, y2.transpose()))

delta_w2
# Out:
# array([[0.02302538, 0.03986217]])

# %%
delta_b2 = delta_y3 * delta_y3
delta_b2
# Out:
# array([[0.06939279]])

# %%
delta_y2 = delta_y3 * np.matmul(W2.transpose(), delta_y3)
delta_y2
# Out:
# array([[-0.02081784],
#        [-0.01387856]])

# %%
delta_y1 = delta_y2 * derivate_sigmoid(y2)
delta_y1
# Out:
# array([[-0.00461558],
#        [-0.00339273]])

# %%
delta_w1 = delta_y1 * (np.matmul(delta_y1, y1.transpose()))

delta_w1
# Out:
# array([[-1.49125231e-05,  6.39108131e-06],
#        [-8.05742749e-06,  3.45318321e-06]])

# %%
delta_b1 = delta_y1 * delta_y1
delta_b1
# Out:
# array([[2.13036044e-05],
#        [1.15106107e-05]])
